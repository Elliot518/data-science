# %% [markdown]
# ## Analyzing the Mean of a dataset

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Load Covid-19 Data

# %%
# Load data into dataframe
covid_data = pd.read_csv("../data/covid-data.csv")

# %% [markdown]
# ### Inspect the dataframe

# %%
covid_data
# Out:
#      iso_code continent     location        date  total_cases  new_cases  \
# 0         AFG      Asia  Afghanistan  24/02/2020            5          5
# 1         AFG      Asia  Afghanistan  25/02/2020            5          0
# 2         AFG      Asia  Afghanistan  26/02/2020            5          0
# 3         AFG      Asia  Afghanistan  27/02/2020            5          0
# 4         AFG      Asia  Afghanistan  28/02/2020            5          0
# ...       ...       ...          ...         ...          ...        ...
# 5813      NGA    Africa      Nigeria  06/10/2022       265741        236
# 5814      NGA    Africa      Nigeria  07/10/2022       265741          0
# 5815      NGA    Africa      Nigeria  08/10/2022       265816         75
# 5816      NGA    Africa      Nigeria  09/10/2022       265816          0
# 5817      NGA    Africa      Nigeria  10/10/2022       265816          0
#
#       new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
# pick the column needed
covid_data = covid_data[['iso_code','continent','location','date','total_cases','new_cases']]
covid_data.head(5)
# Out:
#   iso_code continent     location        date  total_cases  new_cases
# 0      AFG      Asia  Afghanistan  24/02/2020            5          5
# 1      AFG      Asia  Afghanistan  25/02/2020            5          0
# 2      AFG      Asia  Afghanistan  26/02/2020            5          0
# 3      AFG      Asia  Afghanistan  27/02/2020            5          0
# 4      AFG      Asia  Afghanistan  28/02/2020            5          0

# %%
# check the column datatypes
covid_data.dtypes
# Out:
# iso_code       object
# continent      object
# location       object
# date           object
# total_cases     int64
# new_cases       int64
# dtype: object

# %% [markdown]
# ### Apply the mean method from the numpy library on the new_cases column

# %%
data_mean = np.mean(covid_data["new_cases"])
data_mean
# Out:
# 8814.365761430045
