# %%
import pandas as pd

# %%
pd.read_excel("../data/course_participants.xlsx")
# Out:
#    user_id   name  age  country  score continent
# 0     1001   Mark   55    Italy    4.5    Europe
# 1     1000   John   33      USA    6.7   America
# 2     1002    Tim   41      USA    3.9   America
# 3     1003  Jenny   12  Germany    9.0    Europe

# %%
df = pd.read_excel("../data/002648_benefit_report.xlsx", header=None)

# %%
df
# Out:
#                       0              1                   2   \
# 0                    NaN            NaN                 NaN
# 1                  科目\时间     2022-03-31          2021-12-31
# 2              报表核心指标(元)            NaN                 NaN
# 3                *净利润(元)     1531633900          6012789500
# 4              *营业总收入(元)  8137590770.46  28557039117.130001
# 5              *营业总成本(元)     6329509600         21800935100
# 6      *归属于母公司所有者的净利润(元)     1521182600          6006510700
# 7      *扣除非经常性损益后的净利润(元)     1539617300          5851985500
# 8              报表全部指标(元)            NaN                 NaN
# 9             一、营业总收入(元)  8137590770.46  28557039117.130001
# 10            其中：营业收入(元)  8137590770.46  28557039117.130001
# 11            二、营业总成本(元)     6329509600         21800935100
# 12            其中：营业成本(元)     5772821400         19499705500
# 13            营业税金及附加(元)       28748000            95152100
# 14               销售费用(元)       25475800            60007700
# ...

# %%
df.values[0,0]
# Out:
# nan

# %%
df.values[0,1]
# Out:
# nan

# %%
df.values[2,1]
# Out:
# nan

# %%
df.values[3,1]
# Out:
# 1531633900

# %%
df_clean = df.dropna(subset=[0])

# %%
df_clean
# Out:
#                       0              1                   2   \
# 1                  科目\时间     2022-03-31          2021-12-31
# 2              报表核心指标(元)            NaN                 NaN
# 3                *净利润(元)     1531633900          6012789500
# 4              *营业总收入(元)  8137590770.46  28557039117.130001
# 5              *营业总成本(元)     6329509600         21800935100
# 6      *归属于母公司所有者的净利润(元)     1521182600          6006510700
# 7      *扣除非经常性损益后的净利润(元)     1539617300          5851985500
# 8              报表全部指标(元)            NaN                 NaN
# 9             一、营业总收入(元)  8137590770.46  28557039117.130001
# 10            其中：营业收入(元)  8137590770.46  28557039117.130001
# 11            二、营业总成本(元)     6329509600         21800935100
# 12            其中：营业成本(元)     5772821400         19499705500
# 13            营业税金及附加(元)       28748000            95152100
# 14               销售费用(元)       25475800            60007700
# 15               管理费用(元)       80047100           509589200
# ...

# %%
df_clean.values[0,0]
# Out:
# '科目\\时间'

# %%
df_clean.shape[0]
# Out:
# 46

# %%
df_clean.shape[1]
# Out:
# 50

# %%
for (colIndex, columnData) in df_clean.iteritems(): 
    print('Colunm Index : ', colIndex)
    for rowNum in range(1, df_clean.shape[0]+1):
        print('Column Contents : ', columnData[rowNum])
    print("-----------------------------------------------")
# Out:
# Colunm Index :  0
# Column Contents :  科目\时间
# Column Contents :  报表核心指标(元)
# Column Contents :  *净利润(元)
# Column Contents :  *营业总收入(元)
# Column Contents :  *营业总成本(元)
# Column Contents :  *归属于母公司所有者的净利润(元)
# Column Contents :  *扣除非经常性损益后的净利润(元)
# Column Contents :  报表全部指标(元)
# Column Contents :  一、营业总收入(元)
# Column Contents :  其中：营业收入(元)
# Column Contents :  二、营业总成本(元)
# Column Contents :  其中：营业成本(元)
# Column Contents :  营业税金及附加(元)
# Column Contents :  销售费用(元)
# Column Contents :  管理费用(元)
# Column Contents :  研发费用(元)
# Column Contents :  财务费用(元)
# Column Contents :  其中：利息费用(元)
# Column Contents :  利息收入(元)
# Column Contents :  资产减值损失(元)
# Column Contents :  信用减值损失(元)
# Column Contents :  加：公允价值变动收益(元)
# Column Contents :  投资收益(元)
# Column Contents :  其中：联营企业和合营企业的投资收益(元)
# Column Contents :  资产处置收益(元)
# Column Contents :  其他收益(元)
# Column Contents :  三、营业利润(元)
# Column Contents :  加：营业外收入(元)
# Column Contents :  其中：非流动资产处置利得(元)
# Column Contents :  减：营业外支出(元)
# ...
