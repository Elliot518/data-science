# %%
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame(data=np.random.rand(4, 4) * 100000,
                    index=["Q1", "Q2", "Q3", "Q4"],
                    columns=["East", "West", "North", "South"])
data.index.name = "Quarters"
data.columns.name = "Region"
data
# Out:
# Region            East          West         North         South
# Quarters
# Q1        76981.018204   1552.479944  93699.811493  97916.091450
# Q2         7548.571472   3541.540109  55150.762200  11674.580991
# Q3        65532.637470  53556.305419  31364.050993  81696.530113
# Q4        31458.159402  68130.949782  28687.982354  24320.826105

# %%
data.plot()
# Out:
# <Axes: xlabel='Quarters'>
